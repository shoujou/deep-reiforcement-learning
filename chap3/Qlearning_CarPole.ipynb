# %%
# パッケージのimport
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# 動画の描画関数の宣言
# 参考URL http://nbviewer.jupyter.org/github/patrickmineault
# /xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display


def display_frames_as_gif(frames):
    """
    Displays a list of frames as a gif, with controls
    """
    plt.figure(figsize=(frames[0].shape[1]/72.0, frames[0].shape[0]/72.0),
               dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')

    def animate(i):
        patch.set_data(frames[i])

    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
                                   interval=50)

    anim.save('movie_cartpole.mp4')  # 動画のファイル名と保存です
    display(display_animation(anim, default_mode='loop'))

# %%
#定数の設定
ENV = 'CartPole-v0'  # 使用する課題名
NUM_DIZITIZED = 6  # 各状態の離散値への分割数
GAMMA = 0.99  # 時間割引率
ETA = 0.5  # 学習係数
MAX_STEP = 200  # 1試行のstep数
NUM_EPISODES = 1000  # 最大試行回数

# %%
class Agent:
    '''CartPoleのエージェントクラスです、棒付き台車そのものになります'''

    def __init__(self, num_states, num_actions):
        self.brains = Brain(num_states, num_actions) # エージェントが行動を決定するための頭脳を生成
    
    def update_Q_function(self, observation, action, reward, observation_next):
        '''Q関数の更新'''
        self.brains.update_Q_table(
            observation, action, reward, observation_next)

    def get_action(self, observation, step):
         '''行動の決定'''
         action = self.brains.decide_action(observation, step)
         return action

# %%
class Brain:
    '''エージェントが持つ脳となるクラスです、Q学習を実行します'''

    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions # CartPoleの行動（右に左に押す）の2を取得

        # Qテーブルを作成。行数は状態を分割数^（4変数）にデジタル変換した値、列数は行動数を示す
        self.q_table = np.random.uniform(low=0, high=1, size=(
            NUM_DIZITIZED**num_states, num_actions))
        
    def bins(self, clip_min, clip_max, num):
        '''観測した状態（連続値）を離散値にデジタル変換する閾値を求める'''
        return np.linspace(clip_min, clip_max, num+1)[1:-1]

    def digitize_state(self, observation):
        '''観測したobservation状態を、離散値に変換する'''
        cart_pos, cart_v, pole_angle, pole_v = observation
        digitized = [
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x * (NUM_DIZITIZED**i) for i, x in enumerate(digitized)])

    def update_Q_table(self, observation, action, reward, observation_next):
        '''QテーブルをQ学習により更新'''
        state = self.digitize_state(observation) #状態を離散化
        state_next = self.digitize_state(observation_next) #次の状態を離散化
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
            ETA * (reward + GAMMA * Max_Q_next -self.q_table[state, action])
                        
    def decide_action(self, observation, episode):
        '''ε-greedy法で徐々に最適行動のみを採用する'''
        state = self.digitize_state(observation)
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)
        return action

# %%
class Environment:
    '''CartPoleを実行する環境のクラスです'''

    def __init__(self):
        self.env = gym.make(ENV) # 実行する課題を設定
        num_states = self.env.observation_space.shape[0]  # 課題の状態の数4を取得
        num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の2を取得
        self.agent = Agent(num_states, num_actions)   # 環境内で行動するAgentを生成

    def run(self):
        '''実行'''
        complete_episodes = 0 # 195step以上連続で立ち続けた試行数
        is_episode_final = False # 最終試行フラグ
        frames = [] # 動画用に画像を格納する変数

        for episode in range(NUM_EPISODES):  #試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化

            for step in range(MAX_STEP): #1エピソードのステップ

                if is_episode_final is True: # 最終試行ではframesに各時刻の画像を追加していく
                    frames.append(self.env.render(mode='rgb_array'))

                #行動を求める
                action = self.agent.get_action(observation, episode)

                #行動a_tの実行より、s_{t+1}, r_{t+1}を求める
                observation_next, _, done, _ = self.env.step(
                    action)  # rewardとinfoは使わないので_にする
                    
                #報酬を与える
                if done:  # ステップ数が200経過するか、一定角度以上傾くとdoneはtrueになる
                    if step < 195:
                        reward = -1  # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0 #195step以上連続で立ち続けた試行数をリセット
                    else:
                        reward = 1 # 立ったまま終了時は報酬1を与える
                        complete_episodes += 1  # 連続記録を更新
                else:
                    reward = 0  # 途中の報酬は0

                #step+1の状態observation_nextを用いて,Q関数を更新する
                self.agent.update_Q_function(
                    observation, action, reward, observation_next)

                # 観測の更新
                observation = observation_next

                # 終了時の処理
                if done:
                    print('{0} Episode: Finished after {1} time steps'.format(
                        episode, step + 1))
                    break
                
            if is_episode_final is True: # 最終試行では動画を保存と描画
                display_frames_as_gif(frames)
                break

            if complete_episodes >= 10:  # 10連続成功なら
                print('10回連続成功')
                is_episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
# ssh接続だとディスプレイが開けないので
# DummyVideoDriverを使用する
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"

# %%
# main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# /home/nishome/kohei/anaconda3/lib/python3.9/site-packages/gym/envs/registration.py:564: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /home/nishome/kohei/anaconda3/lib/python3.9/site-packages/gym/utils/passive_env_checker.py:97: UserWarning: WARN: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   logger.warn(
# 0 Episode: Finished after 28 time steps
# 1 Episode: Finished after 22 time steps
# 2 Episode: Finished after 15 time steps
# 3 Episode: Finished after 58 time steps
# 4 Episode: Finished after 10 time steps
# 5 Episode: Finished after 10 time steps
# 6 Episode: Finished after 32 time steps
# 7 Episode: Finished after 16 time steps
# 8 Episode: Finished after 27 time steps
# 9 Episode: Finished after 18 time steps
# 10 Episode: Finished after 22 time steps
# 11 Episode: Finished after 28 time steps
# 12 Episode: Finished after 23 time steps
# 13 Episode: Finished after 32 time steps
# 14 Episode: Finished after 22 time steps
# 15 Episode: Finished after 19 time steps
# 16 Episode: Finished after 54 time steps
# 17 Episode: Finished after 42 time steps
# 18 Episode: Finished after 200 time steps
# 19 Episode: Finished after 10 time steps
# 20 Episode: Finished after 25 time steps
# 21 Episode: Finished after 136 time steps
# 22 Episode: Finished after 37 time steps
# 23 Episode: Finished after 36 time steps
# 24 Episode: Finished after 28 time steps
# 25 Episode: Finished after 88 time steps
# 26 Episode: Finished after 99 time steps
# 27 Episode: Finished after 90 time steps
# 28 Episode: Finished after 21 time steps
# 29 Episode: Finished after 137 time steps
# 30 Episode: Finished after 155 time steps
# 31 Episode: Finished after 135 time steps
# 32 Episode: Finished after 64 time steps
# 33 Episode: Finished after 85 time steps
# 34 Episode: Finished after 158 time steps
# 35 Episode: Finished after 39 time steps
# 36 Episode: Finished after 93 time steps
# 37 Episode: Finished after 9 time steps
# 38 Episode: Finished after 10 time steps
# 39 Episode: Finished after 10 time steps
# 40 Episode: Finished after 75 time steps
# 41 Episode: Finished after 61 time steps
# 42 Episode: Finished after 119 time steps
# 43 Episode: Finished after 104 time steps
# 44 Episode: Finished after 26 time steps
# 45 Episode: Finished after 137 time steps
# 46 Episode: Finished after 129 time steps
# 47 Episode: Finished after 43 time steps
# 48 Episode: Finished after 130 time steps
# 49 Episode: Finished after 200 time steps
# 50 Episode: Finished after 170 time steps
# 51 Episode: Finished after 71 time steps
# 52 Episode: Finished after 81 time steps
# 53 Episode: Finished after 200 time steps
# 54 Episode: Finished after 200 time steps
# 55 Episode: Finished after 200 time steps
# 56 Episode: Finished after 130 time steps
# 57 Episode: Finished after 150 time steps
# 58 Episode: Finished after 200 time steps
# 59 Episode: Finished after 185 time steps
# 60 Episode: Finished after 56 time steps
# 61 Episode: Finished after 113 time steps
# 62 Episode: Finished after 139 time steps
# 63 Episode: Finished after 146 time steps
# 64 Episode: Finished after 126 time steps
# 65 Episode: Finished after 29 time steps
# 66 Episode: Finished after 28 time steps
# 67 Episode: Finished after 11 time steps
# 68 Episode: Finished after 39 time steps
# 69 Episode: Finished after 21 time steps
# 70 Episode: Finished after 64 time steps
# 71 Episode: Finished after 47 time steps
# 72 Episode: Finished after 18 time steps
# 73 Episode: Finished after 19 time steps
# 74 Episode: Finished after 10 time steps
# 75 Episode: Finished after 22 time steps
# 76 Episode: Finished after 34 time steps
# 77 Episode: Finished after 11 time steps
# 78 Episode: Finished after 18 time steps
# 79 Episode: Finished after 24 time steps
# 80 Episode: Finished after 15 time steps
# 81 Episode: Finished after 13 time steps
# 82 Episode: Finished after 53 time steps
# 83 Episode: Finished after 108 time steps
# 84 Episode: Finished after 87 time steps
# 85 Episode: Finished after 72 time steps
# 86 Episode: Finished after 126 time steps
# 87 Episode: Finished after 77 time steps
# 88 Episode: Finished after 62 time steps
# 89 Episode: Finished after 58 time steps
# 90 Episode: Finished after 56 time steps
# 91 Episode: Finished after 54 time steps
# 92 Episode: Finished after 37 time steps
# 93 Episode: Finished after 189 time steps
# 94 Episode: Finished after 200 time steps
# 95 Episode: Finished after 31 time steps
# 96 Episode: Finished after 91 time steps
# 97 Episode: Finished after 45 time steps
# 98 Episode: Finished after 192 time steps
# 99 Episode: Finished after 128 time steps
# 100 Episode: Finished after 200 time steps
# 101 Episode: Finished after 166 time steps
# 102 Episode: Finished after 141 time steps
# 103 Episode: Finished after 200 time steps
# 104 Episode: Finished after 97 time steps
# 105 Episode: Finished after 18 time steps
# 106 Episode: Finished after 157 time steps
# 107 Episode: Finished after 64 time steps
# 108 Episode: Finished after 130 time steps
# 109 Episode: Finished after 54 time steps
# 110 Episode: Finished after 200 time steps
# 111 Episode: Finished after 27 time steps
# 112 Episode: Finished after 92 time steps
# 113 Episode: Finished after 200 time steps
# 114 Episode: Finished after 61 time steps
# 115 Episode: Finished after 116 time steps
# 116 Episode: Finished after 33 time steps
# 117 Episode: Finished after 79 time steps
# 118 Episode: Finished after 99 time steps
# 119 Episode: Finished after 141 time steps
# 120 Episode: Finished after 40 time steps
# 121 Episode: Finished after 81 time steps
# 122 Episode: Finished after 26 time steps
# 123 Episode: Finished after 137 time steps
# 124 Episode: Finished after 200 time steps
# 125 Episode: Finished after 77 time steps
# 126 Episode: Finished after 119 time steps
# 127 Episode: Finished after 168 time steps
# 128 Episode: Finished after 138 time steps
# 129 Episode: Finished after 199 time steps
# 130 Episode: Finished after 36 time steps
# 131 Episode: Finished after 109 time steps
# 132 Episode: Finished after 90 time steps
# 133 Episode: Finished after 113 time steps
# 134 Episode: Finished after 73 time steps
# 135 Episode: Finished after 44 time steps
# 136 Episode: Finished after 200 time steps
# 137 Episode: Finished after 133 time steps
# 138 Episode: Finished after 70 time steps
# 139 Episode: Finished after 88 time steps
# 140 Episode: Finished after 113 time steps
# 141 Episode: Finished after 162 time steps
# 142 Episode: Finished after 200 time steps
# 143 Episode: Finished after 122 time steps
# 144 Episode: Finished after 70 time steps
# 145 Episode: Finished after 83 time steps
# 146 Episode: Finished after 200 time steps
# 147 Episode: Finished after 113 time steps
# 148 Episode: Finished after 200 time steps
# 149 Episode: Finished after 200 time steps
# 150 Episode: Finished after 200 time steps
# 151 Episode: Finished after 200 time steps
# 152 Episode: Finished after 200 time steps
# 153 Episode: Finished after 200 time steps
# 154 Episode: Finished after 200 time steps
# 155 Episode: Finished after 200 time steps
# 156 Episode: Finished after 200 time steps
# 157 Episode: Finished after 200 time steps
# 10回連続成功
# 158 Episode: Finished after 193 time steps
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb Cell 8' in <cell line: 3>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000006vscode-remote?line=0'>1</a> # main
#       <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000006vscode-remote?line=1'>2</a> cartpole_env = Environment()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000006vscode-remote?line=2'>3</a> cartpole_env.run()
#
# /home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb Cell 6' in Environment.run(self)
#      <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000005vscode-remote?line=52'>53</a>         break
#      <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000005vscode-remote?line=54'>55</a> if is_episode_final is True: # 最終試行では動画を保存と描画
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000005vscode-remote?line=55'>56</a>     display_frames_as_gif(frames)
#      <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000005vscode-remote?line=56'>57</a>     break
#      <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000005vscode-remote?line=58'>59</a> if complete_episodes >= 10:  # 10連続成功なら
#
# /home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb Cell 2' in display_frames_as_gif(frames)
#      <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000001vscode-remote?line=20'>21</a> anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames),
#      <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000001vscode-remote?line=21'>22</a>                                interval=50)
#      <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000001vscode-remote?line=23'>24</a> anim.save('movie_cartpole.mp4')  # 動画のファイル名と保存です
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bkeisan/home/nishome/kohei/workspase/deep-reiforcement-learning/chap3/Qlearning_CarPole.ipynb#ch0000001vscode-remote?line=24'>25</a> display(display_animation(anim, default_mode='loop'))
#
# File ~/anaconda3/lib/python3.9/site-packages/JSAnimation/IPython_display.py:86, in display_animation(anim, **kwargs)
#      84 """Display the animation with an IPython HTML object"""
#      85 from IPython.display import HTML
# ---> 86 return HTML(anim_to_html(anim, **kwargs))
#
# File ~/anaconda3/lib/python3.9/site-packages/JSAnimation/IPython_display.py:74, in anim_to_html(anim, fps, embed_frames, default_mode)
#      69 else:
#      70     # tempfile can't be used here: we need a filename, and this
#      71     # fails on windows.  Instead, we use a custom filename generator
#      72     #with tempfile.NamedTemporaryFile(suffix='.html') as f:
#      73     with _NameOnlyTemporaryFile(suffix='.html') as f:
# ---> 74         anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                              embed_frames=embed_frames,
#      76                                              default_mode=default_mode))
#      77         html = open(f.name).read()
#      79     anim._html_representation = html
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py:1073, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1067     _log.info("Disabling savefig.bbox = 'tight', as it may cause "
#    1068               "frame size to vary, which is inappropriate for "
#    1069               "animation.")
#    1070 # canvas._is_saving = True makes the draw_event animation-starting
#    1071 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1072 # widget (both are likewise done in savefig()).
# -> 1073 with mpl.rc_context({'savefig.bbox': None}), \
#    1074      writer.saving(self._fig, filename, dpi), \
#    1075      cbook._setattr_cm(self._fig.canvas,
#    1076                        _is_saving=True, manager=None):
#    1077     for anim in all_anim:
#    1078         anim._init_draw()  # Clear the initial frame
#
# File ~/anaconda3/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py:234, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     228 """
#     229 Context manager to facilitate writing the movie file.
#     230
#     231 ``*args, **kw`` are any parameters that should be passed to `setup`.
#     232 """
#     233 # This particular sequence is what contextlib.contextmanager wants
# --> 234 self.setup(fig, outfile, dpi, *args, **kwargs)
#     235 try:
#     236     yield self
#
# File ~/anaconda3/lib/python3.9/site-packages/JSAnimation/html_writer.py:281, in HTMLWriter.setup(self, fig, outfile, dpi, frame_dir)
#     278 else:
#     279     frame_prefix = None
# --> 281 super(HTMLWriter, self).setup(fig, outfile, dpi,
#     282                               frame_prefix, clear_temp=False)
#
# TypeError: setup() got an unexpected keyword argument 'clear_temp'
